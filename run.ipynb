# %%
import sys
sys.path.append('.')

from qiskit import Aer
from qiskit.providers.fake_provider import FakeManilaV2

from HamilToniQ.benchmarking import Toniq

#backend = Aer.get_backend("statevector_simulator")
backend = FakeManilaV2()

tonic = Toniq()
tonic.standard_QAOA(backend)
# Out:
# array([2.2288435 , 3.40497974, 1.81092751, 1.79754266, 2.14756214,
#        1.92808549, 3.25227832, 2.2124287 , 2.36846378, 1.99597462,
#        2.99404234, 2.00127996])
